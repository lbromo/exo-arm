# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (14, 8)
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
emg = pd.read_csv('emg.log')
emg.columns = ['1', '2', '3', '4', '5', '6', '7', '8']

# %%
emg.plot()

# %%
gyro = pd.read_csv('gyro.log')
gyro.columns = ['x', 'y', 'z']

# %%
gyro.plot()

# %%
acc = pd.read_csv('acc.log')
acc.columns = ['x', 'y', 'z']

# %%
acc.plot()

# %%
acc
# Out:
#          x    y     z
# 0     1647  440  1025
# 1     1657  372  1029
# 2     1642  223  1057
# 3     1657  123  1042
# 4     1685   96  1029
# 5     1695  120  1013
# 6     1668  165  1017
# 7     1670  161   994
# 8     1678  181   990
# 9     1652  229   991
# 10    1666  240  1004
# 11    1667  225  1001
# 12    1666  189  1007
# 13    1659  203  1030
# 14    1678  197  1050
# 15    1685  152  1063
# 16    1679  182  1061
# 17    1648  209  1104
# 18    1633  182  1090
# 19    1675  190  1034
# 20    1696  276   991
# 21    1694  331   948
# 22    1700  311   944
# 23    1724  273   929
# 24    1721  301   934
# 25    1705  295   979
# 26    1680  230  1015
# 27    1669  140  1036
# 28    1657  156  1045
# 29    1665  184  1050
# ...    ...  ...   ...
# 1704  1690  102  1027
# 1705  1718  190  1000
# 1706  1726  235   980
# 1707  1747  218   962
# 1708  1713  178   914
# 1709  1646  155   915
# 1710  1629  101   938
# 1711  1672   95   939
# 1712  1645   90   923
# ...
